# %%
import pandas as pd 
df = pd.read_excel('../dataset/FinalDataset.xlsx')

# %%
df.head(60)
# Out:
#                                                  tags  \
# 0                              ['আমেরিকা  দূর পরবাস']
# 1                                 ['বিবিধ', 'বিনোদন']
# 2                            ['বিবিধ', 'বিশাল বাংলা']
# 3                               ['মতামত', 'চিঠিপত্র']
# 4   ['বিবিধ', 'বিশাল বাংলা', 'রংপুর বিভাগ', 'দিনাজ...
# 5                             ['আন্তর্জাতিক ক্রিকেট']
# 6   ['বিবিধ', 'বিশাল বাংলা', 'পাবনা', 'রাজশাহী বিভ...
# 7   ['ঢাকা', 'সিটি নির্বাচন', 'নির্বাচন', 'ঢাকা বি...
# 8                             ['চলচ্চিত্র', 'বিনোদন']
# 9   ['বিবিধ', 'দেশ', 'চট্টগ্রাম', 'সীতাকুণ্ড', 'চট...
# 10                                          ['অপরাধ']
# 11                      ['খেলা', 'আন্তর্জাতিক ফুটবল']
# 12                          ['বিবিধ', 'শেষের পৃষ্ঠা']
# 13                                 ['আমার চট্টগ্রাম']
# 14                                          ['বিবিধ']
# 15   ['বিশাল বাংলা', 'ইসলামী বিশ্ববিদ্যালয়', 'অপরাধ']
# ...
